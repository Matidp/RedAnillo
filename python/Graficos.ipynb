# %% [markdown]
# # Laboratorio 4 - Redes y Sistemas Distribuidos

# %%
import datos
import matplotlib.pylab as plt
import seaborn
#plt.style.use("fivethirtyeight")
#seaborn.set_style("darkgrid", {"axes.facecolor": ".85"})

# %% [markdown]
# # Tarea Analisis (Caso Base)

# %%
#plt.style.use("fivethirtyeight")
##Estos graficos los pueden ver individualmente con la funcion:
## "delay_por_conexion"

datos.comp_delay_por_conexion("base", "caso1")
datos.comp_delay_por_conexion("base", "caso2")

# %%
datos.gdelay_por_escenario("base", "caso1")
datos.gdelay_por_escenario("base", "caso2")

# %%
plt.style.use("fivethirtyeight")
seaborn.set_style("darkgrid", {"axes.facecolor": ".85"})

datos.comp_ocupacion_buffers("base", "caso1")
datos.comp_ocupacion_buffers("base", "caso2")

# %%
datos.comp_pkts_proc("base", "caso1")
datos.comp_pkts_proc("base", "caso2")

# %%
datos.comp_esc_ocurs("base", "caso1", "hopc")
datos.comp_esc_ocurs("base", "caso1", "source")

# %%
datos.comp_esc_ocurs("base", "caso2", "hopc")
datos.comp_esc_ocurs("base", "caso2", "source")

# %% [markdown]
# # Comparando Algoritmos
# ## Comparar Ocurrencias
# Compara algoritmos por:
# * Caso
# * Escenario
# * Metrica:
#     + Nodo Emisor ("source")
#     + Cantidad de Saltos ("hopc")

# %%
datos.compare_algorithms_ocurs("caso2", "1", "source")
datos.compare_algorithms_ocurs("caso2", "2", "source")
datos.compare_algorithms_ocurs("caso2", "3.5", "source")
datos.compare_algorithms_ocurs("caso2", "7", "source")

# %%
datos.compare_algorithms_ocurs("caso2", "1", "hopc")
datos.compare_algorithms_ocurs("caso2", "2", "hopc")
datos.compare_algorithms_ocurs("caso2", "3.5", "hopc")
datos.compare_algorithms_ocurs("caso2", "7", "hopc")
