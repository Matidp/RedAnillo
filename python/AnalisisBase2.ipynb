# %% [markdown]
# # Laboratorio 4 - Redes y Sistemas Distribuidos

# %%
import analisis as an
import matplotlib.pylab as plt
import seaborn
#plt.style.use("fivethirtyeight")
#seaborn.set_style("darkgrid", {"axes.facecolor": ".85"})

# %% [markdown]
# # Tarea Analisis (Caso Base)
#
# ## Caso 2
# ### Delay por conexion

# %%
an.comp_delay_por_conexion("base", "caso2")

# %% [markdown]
# # Delay General

# %%
an.gdelay_por_escenario("base", "caso2")

# %% [markdown]
# ### Ocupación Buffers

# %%
plt.style.use("fivethirtyeight")
seaborn.set_style("darkgrid", {"axes.facecolor": ".9"})
an.comp_ocupacion_buffers("base", "caso2")

# %% [markdown]
# ### Paquetes procesados

# %%
an.comp_pkts_proc("base", "caso2")

# %% [markdown]
# ### Cantidad de Saltos

# %%
an.comp_esc_ocurs("base", "caso2", "hopc")

# %% [markdown]
# ### Pquetes recividos de cada Nodo

# %%
an.comp_esc_ocurs("base", "caso2", "source")

# %% [markdown]
# ### Monitoreando el equilibrio (analisis en 1000 segundos)
# (te debo el grafico por hoy)

# %%
an.gdelay_por_escenario("base", "caso2")
